# %% [markdown]
# # Week 3 Day 2 Lab
#
# ### Problem 1
# Plot the function $f(x)=x^2$ for $x\in [-1,1]$ using `np.linspace()` with 10, 100, 1000 slices. Make sure your plot is as informative as possible.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
for i in [10,100,1000]:
    x = np.linspace(-1, 1, i)
    plt.title('$x^2$ on [-1,1] with '+str(i)+' Slices')
    plt.xlabel('x value')
    plt.ylabel('$x^2$ value')
    plt.scatter(x, x**2, 
                label=str(i)+' Slices')
    plt.show()

# %% [markdown]
# ### Problem 2
# Pick a function $f(x)$ you like and plot some values using `plt.scatter()`. Make sure your plot is as informative as possible.

# %%
x = np.linspace(.01,100, 1000)
plt.scatter(x, np.sin(x)/x)
plt.title('Sine over X')
plt.xlabel('X Value')
plt.ylabel('Function Value')
# Out:
# Text(0, 0.5, 'Function Value')

# %% [markdown]
# ### Problem 3
# Download the "Horses.xlsx" or "Horses.csv" file.
# - Read the file in using `pandas`
# - Plot the values using whatever plot type you like. Make sure your plot is as informative as possible.

# %%
pd.read_csv("Datasets/Horses.csv")
# Out:
#   Horse  Race Finish Time
# 0     A              1230
# 1     B              1309
# 2     C              1279
# 3     D              1237
# 4     E              1328
# 5     F              1490
# 6     G              1243
# 7     H              1325
# 8     I              1428

# %%
data = pd.read_csv("Datasets/Horses.csv")
xdata = data['Horse']
ydata = data['Race Finish Time']

# %%
plt.scatter(xdata, ydata)

# %% [markdown]
# ### Problem 4
# Download the "WA_County_Boundaries.shp" file.
# - Plot the state using `name_of_file_read.plot()`
# - Plot some information about the state by extracting two columns of data.

# %%
import geopandas as gpd

# %%
washington = gpd.read_file(r"C:\Users\Garrett\Downloads\WA_County_Boundaries\WA_County_Boundaries.shp")

# %%
washington
# Out:
#     OBJECTID  JURISDICT_  JURISDIC_1    JURISDIC_2           JURISDIC_3  \
# 0    2229338          25           4         Grant         Grant County
# 1    2231411     4698174           4  Pend Oreille  Pend Oreille County
# 2    2231418     4698173           4       Stevens       Stevens County
# 3    2233491          33           4      Garfield      Garfield County
# 4    2233852           8           4        Island        Island County
# 5    2234461          20           4  Grays Harbor  Grays Harbor County
# 6    2234462     4692894           4      Thurston      Thurston County
# 7    2234463          27           4         Lewis         Lewis County
# 8    2234464           4           4        Skagit        Skagit County
# 9    2234465     4690632           4       Whatcom       Whatcom County
# 10   2234523          35           4   Walla Walla   Walla Walla County
# 11   2234542          34           4      Columbia      Columbia County
# 12   2234583          32           4        Asotin        Asotin County
# 13   2234599          29           4      Franklin      Franklin County
# 14   2234682          17           4       Douglas       Douglas County
# 15   2234717     4699352           4     Snohomish     Snohomish County
# 16   2234718           9           4         Ferry         Ferry County
# 17   2234733          12           4     Jefferson     Jefferson County
# 18   2234734          39           4      Skamania      Skamania County
# 19   2234735          23           4         Adams         Adams County
# 20   2234741     4692563           4        Pierce        Pierce County
# 21   2234768          38           4     Klickitat     Klickitat County
# 22   2234784          18           4         Mason         Mason County
# 23   2234785     4698638           4        Kitsap        Kitsap County
# 24   2234811          30           4     Wahkiakum     Wahkiakum County
#                                              geometry
# 0   POLYGON ((-13245041.204 6100462.041, -13245049...
# 1   POLYGON ((-13028207.663 6215102.773, -13028213...
# 2   POLYGON ((-13072259.109 6271668.868, -13072256...
# 3   POLYGON ((-13077215.155 5893282.479, -13076922...
# 4   POLYGON ((-13645903.473 6175425.382, -13645833...
# 5   POLYGON ((-13818358.748 6029600.620, -13817157...
# 6   POLYGON ((-13668140.191 5968532.266, -13667828...
# 7   POLYGON ((-13726667.316 5908398.973, -13724294...
# 8   POLYGON ((-13646976.232 6211587.326, -13646829...
# 9   POLYGON ((-13661948.246 6275217.332, -13660730...
# 10  POLYGON ((-13170470.944 5878093.595, -13170220...
# 11  POLYGON ((-13119277.932 5875313.561, -13119349...
# 12  POLYGON ((-13046628.720 5847940.517, -13046278...
# 13  POLYGON ((-13159766.598 5899385.299, -13159880...
# 14  POLYGON ((-13257560.068 6129730.973, -13257263...
# 15  POLYGON ((-13601415.957 6156455.175, -13601292...
# 16  POLYGON ((-13157667.072 6274864.610, -13157440...
# 17  POLYGON ((-13653405.352 6126390.566, -13653235...
# 18  POLYGON ((-13593638.701 5842796.230, -13591537...
# 19  POLYGON ((-13131350.696 5984709.557, -13131339...
# 20  POLYGON ((-13651653.941 6008143.837, -13651640...
# 21  POLYGON ((-13527802.842 5787404.070, -13526218...
# 22  POLYGON ((-13736648.080 6041327.062, -13734265...
# 23  POLYGON ((-13632070.339 6053935.446, -13632151...
# 24  POLYGON ((-13736747.915 5842104.061, -13735718...
# 25  POLYGON ((-13794176.032 5908293.996, -13792142...
# 26  POLYGON ((-13228357.287 6097273.339, -13228274...
# 27  POLYGON ((-13762933.712 6146044.720, -13752545...
# 28  POLYGON ((-13702664.169 5842750.924, -13700419...
# 29  POLYGON ((-13029073.626 6071491.429, -13029068...
# 30  POLYGON ((-13593254.964 6069657.588, -13592053...
# 31  POLYGON ((-13028819.631 5984496.998, -13028817...
# 32  POLYGON ((-13228831.248 6274874.740, -13228837...
# 33  POLYGON ((-13678738.782 6239384.542, -13678710...
# 34  POLYGON ((-13609304.472 5789347.279, -13609297...
# 35  POLYGON ((-13451695.289 6198988.419, -13451524...
# 36  POLYGON ((-13500270.861 5956159.912, -13500209...
# 37  POLYGON ((-13292341.455 5883579.005, -13292340...
# 38  POLYGON ((-13482428.890 6040101.397, -13482417...

# %%
washington.columns
# Out:
# Index(['OBJECTID', 'JURISDICT_', 'JURISDIC_1', 'JURISDIC_2', 'JURISDIC_3',
#        'JURISDIC_4', 'JURISDIC_5', 'JURISDIC_6', 'EDIT_DATE', 'EDIT_STATU',
#        'EDIT_WHO', 'GLOBALID', 'geometry'],
#       dtype='object')

# %%
washington.plot('JURISDIC_4')
plt.title('Jurisdiction Identifier 4')
plt.axis('off')
# Out:
# (-13943667.86142592, -12970719.34824518, 5679143.007630255, 6303661.1912448965)

# %%
washington.plot('JURISDIC_5')
plt.title('Jurisdiction Identifier 5')
plt.axis('off')
# Out:
# (-13943667.86142592, -12970719.34824518, 5679143.007630255, 6303661.1912448965)
